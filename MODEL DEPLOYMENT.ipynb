# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.pipeline import Pipeline
import pickle

# %%
df = pd.read_csv("insurance_real.csv")

# %%
from sklearn.linear_model import SGDRegressor

sgd_en = SGDRegressor(
    loss="squared_error",
    penalty="elasticnet",
    alpha=0.01,
    l1_ratio=0.5,   
    learning_rate="constant",
    eta0=0.01,
    max_iter=1000,
    random_state=42
)

# %%
trf_scaling_ohe = ColumnTransformer([
    ("ss_X", StandardScaler(), [0,2]),
    ("ohe_X", OneHotEncoder(sparse_output = False, handle_unknown = "ignore"), [1,4,5])
], remainder = "passthrough")

# %%
pipe = Pipeline([
    ('trf_scaling', trf_scaling_ohe),
    ('regression', sgd_en)
])

model = TransformedTargetRegressor(
    regressor = pipe,
    transformer = StandardScaler()
)

# %%
model.fit(df.iloc[:, :-1], df.iloc[:,-1])
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('trf_scaling',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         transformers=[('ss_X',
#                                                                                        StandardScaler(),
#                                                                                        [0,
#                                                                                         2]),
#                                                                                       ('ohe_X',
#                                                                                        OneHotEncoder(handle_unknown='ignore',
#                                                                                                      sparse_output=False),
# ...

# %%
pickle.dump(model, open("insurance_model.pk1", 'wb'))

# %%
print(df.dtypes)
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
model.predict(df.iloc[1, :-1]).items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Nikhil/PROGRAMMING/ds/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2764, in _check_n_features(estimator, X, reset)
#    2763 try:
# -> 2764     n_features = _num_features(X)
#    2765 except TypeError as e:
#
# File ~/Nikhil/PROGRAMMING/ds/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:352, in _num_features(X)
#     351     message += f" with shape {X.shape}"
# --> 352     raise TypeError(message)
#     353 return X.shape[1]
#
# TypeError: Unable to find the number of features from X of type pandas.core.series.Series with shape (6,)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.predict(df.iloc[1, :-1]).items()
#
# ...
